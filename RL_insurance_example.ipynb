# %%
# !pip install gymnasium stable_baselines3[extra]
# Out:
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.10/dist-packages (0.28.1)
# Requirement already satisfied: stable_baselines3[extra] in /usr/local/lib/python3.10/dist-packages (2.0.0)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (1.23.5)
# Requirement already satisfied: jax-jumpy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (1.0.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (4.7.1)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (0.0.4)
# Requirement already satisfied: torch>=1.11 in /usr/local/lib/python3.10/dist-packages (from stable_baselines3[extra]) (2.0.1+cu118)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from stable_baselines3[extra]) (1.5.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from stable_baselines3[extra]) (3.7.1)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from stable_baselines3[extra]) (4.7.0.72)
# Requirement already satisfied: tensorboard>=2.9.1 in /usr/local/lib/python3.10/dist-packages (from stable_baselines3[extra]) (2.12.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from stable_baselines3[extra]) (5.9.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from stable_baselines3[extra]) (4.65.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from stable_baselines3[extra]) (13.5.2)
# Requirement already satisfied: shimmy[atari]~=0.2.1 in /usr/local/lib/python3.10/dist-packages (from stable_baselines3[extra]) (0.2.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from stable_baselines3[extra]) (9.4.0)
# Requirement already satisfied: autorom[accept-rom-license]~=0.6.0 in /usr/local/lib/python3.10/dist-packages (from stable_baselines3[extra]) (0.6.1)
# Requirement already satisfied: pygame in /usr/local/lib/python3.10/dist-packages (from stable_baselines3[extra]) (2.5.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from autorom[accept-rom-license]~=0.6.0->stable_baselines3[extra]) (8.1.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from autorom[accept-rom-license]~=0.6.0->stable_baselines3[extra]) (2.31.0)
# Requirement already satisfied: AutoROM.accept-rom-license in /usr/local/lib/python3.10/dist-packages (from autorom[accept-rom-license]~=0.6.0->stable_baselines3[extra]) (0.6.1)
# Requirement already satisfied: ale-py~=0.8.1 in /usr/local/lib/python3.10/dist-packages (from shimmy[atari]~=0.2.1->stable_baselines3[extra]) (0.8.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable_baselines3[extra]) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable_baselines3[extra]) (1.56.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable_baselines3[extra]) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable_baselines3[extra]) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable_baselines3[extra]) (3.4.4)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable_baselines3[extra]) (3.20.3)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable_baselines3[extra]) (67.7.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable_baselines3[extra]) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable_baselines3[extra]) (2.3.6)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable_baselines3[extra]) (0.41.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable_baselines3[extra]) (3.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable_baselines3[extra]) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable_baselines3[extra]) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable_baselines3[extra]) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable_baselines3[extra]) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.11->stable_baselines3[extra]) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.11->stable_baselines3[extra]) (16.0.6)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3[extra]) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3[extra]) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3[extra]) (4.42.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3[extra]) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3[extra]) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3[extra]) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3[extra]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable_baselines3[extra]) (2022.7.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->stable_baselines3[extra]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->stable_baselines3[extra]) (2.14.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from ale-py~=0.8.1->shimmy[atari]~=0.2.1->stable_baselines3[extra]) (6.0.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable_baselines3[extra]) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable_baselines3[extra]) (0.3.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable_baselines3[extra]) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable_baselines3[extra]) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.9.1->stable_baselines3[extra]) (1.3.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->stable_baselines3[extra]) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.6.0->stable_baselines3[extra]) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.6.0->stable_baselines3[extra]) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.6.0->stable_baselines3[extra]) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.6.0->stable_baselines3[extra]) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable_baselines3[extra]) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11->stable_baselines3[extra]) (1.3.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable_baselines3[extra]) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.9.1->stable_baselines3[extra]) (3.2.2)

# %%
import numpy as np
import gymnasium as gym
import random

class HikingEnv(gym.Env):
    """
    Custom Environment for hiking insurance company.
    """
    # google colab - no GUI
    metadata = {"render_modes": ["console"]}

    # Define constants for clearer code
    REFUSE = 0
    APPROVE = 1

    def __init__(self, customers=10, render_mode="console"):
        super(HikingEnv, self).__init__()
        self.render_mode = render_mode

        # Initialize parameters
        # Simulation params
        self.customers = customers
        self.step_n = 0


        # Episode params
        self.balance = 35
        self.hiker_experience = 0.0
        self.hiker_age = 10
        self.refusal_cost = 15

        # Secret info about the paycheck - model gets it only once it decides to insure
        self.customer_paycheck_SECRET = 0

        # Define action and observation space. They must be gym.spaces objects
        n_actions = 2
        self.action_space = gym.spaces.discrete.Discrete(n_actions)

        # Our observation space:
        # balance - if it goes under 0 then we lose
        # HikerExperience - 0%-100%
        # HikerAge - 10-90
        # Refusal cost 15+5*x
        self.observation_space = gym.spaces.Box(low=np.array([0.0, 0.0, 10.0, 15.0]),
                                                high=np.array([100000.0, 1.0, 90.0, 265.0]), dtype=np.float32)

    def get_new_customer(self):
        #Function for generating examples - in a actual scenario we would have historical data

        # Generate customer data - "unreal" uniform distribution for demo purposes
        self.hiker_experience = round(random.random(), 3)
        self.hiker_age = random.randint(10, 90)
        accident_probability = random.random()

        if (self.hiker_experience*0.6 + self.hiker_age*0.001 + 0.0) > accident_probability:
          self.customer_paycheck_SECRET = 0
        elif random.random() < 0.75:
          self.customer_paycheck_SECRET = random.randint(-500, -10)
        else:
          if self.hiker_age < 20:
            self.customer_paycheck_SECRET = -1000
          else:
            self.customer_paycheck_SECRET = random.choice([0, -1000])

    def reset(self, seed=None, options=None):
        super().reset(seed=None, options=options)
        # Reset values to defaults and
        self.step_n = 0
        self.balance = 35
        self.refusal_cost = 15
        self.get_new_customer()
        # convert values to float32 to make it more general
        return np.array(([self.balance, self.hiker_experience, self.hiker_age, self.refusal_cost])).astype(np.float32), {}

    def step(self, action):
        self.step_n += 1
        if action == self.REFUSE:
            reward = -self.refusal_cost
            self.refusal_cost += 5 # Every subsequent refusal is more expensive
        elif action == self.APPROVE:
            reward = 150
            reward += self.customer_paycheck_SECRET  # Temporary simplification
        else:
            raise ValueError(
                f"Received invalid action={action} which is not part of the action space")

        self.balance += reward

        terminated = bool(self.step_n >= self.customers)
        if terminated:
          reward = self.balance
        truncated = bool(self.balance < 0)
        if truncated:
          reward = -4000
        info = {}

        self.get_new_customer()
        return (
            np.array(([self.balance, self.hiker_experience, self.hiker_age, self.refusal_cost])).astype(np.float32),
            reward,
            terminated,
            truncated,
            info,
        )

    def render(self):
        if self.render_mode == "console":
            print(f"\t Balance: {self.balance}")
            print(f"\t Hiker's experience: {self.hiker_experience:.1%} age: {self.hiker_age:n} Probable paycheck: {self.customer_paycheck_SECRET}")

    def close(self):
        pass

# %%
from stable_baselines3 import PPO, A2C, DQN
from stable_baselines3.common.env_util import make_vec_env
from gymnasium.wrappers import FlattenObservation

# Instantiate the env
vec_env = make_vec_env(HikingEnv, n_envs=1, env_kwargs=dict(customers=25))
env = HikingEnv(customers=25)
# Train the agent
model = PPO("MlpPolicy", env, verbose=0).learn(10000)

# Showcase the learned behaviour
obs = vec_env.reset()
n_steps = 100
for step in range(n_steps):
    action, _ = model.predict(obs, deterministic=True)
    print(f"Step {step + 1}")
    vec_env.render()
    print("\t Action: ", action)
    obs, reward, done, info = vec_env.step(action)
    # print("obs=", obs, "reward=", reward, "done=", done)
    print("\t reward=", reward, "done=", done)
    if done:
        # Note that the VecEnv resets automatically when a done signal is encountered
        print("-"*20+"Episode ends!", "reward=", reward, "-"*20)
        obs = vec_env.reset()
# Out:
# Step 1
# 	 Balance: 35
# 	 Hiker's experience: 39.6% age: 80 Probable paycheck: -232
# 	 Action:  [1]
# 	 reward= [-4000.] done= [ True]
# --------------------Episode ends! reward= [-4000.] --------------------
# Step 2
# 	 Balance: 35
# 	 Hiker's experience: 18.2% age: 88 Probable paycheck: -428
# 	 Action:  [1]
# 	 reward= [-4000.] done= [ True]
# --------------------Episode ends! reward= [-4000.] --------------------
# Step 3
# 	 Balance: 35
# 	 Hiker's experience: 75.3% age: 34 Probable paycheck: 0
# 	 Action:  [1]
# 	 reward= [150.] done= [False]
# Step 4
# 	 Balance: 185
# 	 Hiker's experience: 68.1% age: 58 Probable paycheck: 0
# 	 Action:  [1]
# 	 reward= [150.] done= [False]
# Step 5
# 	 Balance: 335
# 	 Hiker's experience: 55.9% age: 64 Probable paycheck: -406
# 	 Action:  [0]
# 	 reward= [-15.] done= [False]
# Step 6
# 	 Balance: 320
# 	 Hiker's experience: 17.1% age: 67 Probable paycheck: -94
# 	 Action:  [0]
# 	 reward= [-20.] done= [False]
# Step 7
# 	 Balance: 300
# 	 Hiker's experience: 3.0% age: 82 Probable paycheck: 0
# 	 Action:  [0]
# 	 reward= [-25.] done= [False]
# Step 8
# 	 Balance: 275
# 	 Hiker's experience: 69.4% age: 77 Probable paycheck: -1000
# 	 Action:  [1]
# 	 reward= [-4000.] done= [ True]
# --------------------Episode ends! reward= [-4000.] --------------------
# Step 9
# 	 Balance: 35
# 	 Hiker's experience: 72.4% age: 63 Probable paycheck: 0
# 	 Action:  [1]
# 	 reward= [150.] done= [False]
# Step 10
# 	 Balance: 185
# 	 Hiker's experience: 8.3% age: 83 Probable paycheck: -68
# 	 Action:  [1]
# 	 reward= [82.] done= [False]
# Step 11
# 	 Balance: 267
# 	 Hiker's experience: 34.0% age: 59 Probable paycheck: 0
# 	 Action:  [0]
# 	 reward= [-15.] done= [False]
# Step 12
# 	 Balance: 252
# 	 Hiker's experience: 78.1% age: 79 Probable paycheck: -417
# 	 Action:  [1]
# 	 reward= [-4000.] done= [ True]
# --------------------Episode ends! reward= [-4000.] --------------------
# Step 13
# 	 Balance: 35
# 	 Hiker's experience: 86.4% age: 66 Probable paycheck: -401
# 	 Action:  [1]
# 	 reward= [-4000.] done= [ True]
# --------------------Episode ends! reward= [-4000.] --------------------
# Step 14
# 	 Balance: 35
# 	 Hiker's experience: 33.9% age: 78 Probable paycheck: -392
# 	 Action:  [1]
# 	 reward= [-4000.] done= [ True]
# --------------------Episode ends! reward= [-4000.] --------------------
# Step 15
# 	 Balance: 35
# 	 Hiker's experience: 55.1% age: 59 Probable paycheck: 0
# 	 Action:  [1]
# 	 reward= [150.] done= [False]
# Step 16
# 	 Balance: 185
# 	 Hiker's experience: 49.3% age: 49 Probable paycheck: 0
# 	 Action:  [0]
# 	 reward= [-15.] done= [False]
# Step 17
# 	 Balance: 170
# 	 Hiker's experience: 67.3% age: 29 Probable paycheck: -348
# 	 Action:  [0]
# 	 reward= [-20.] done= [False]
# Step 18
# 	 Balance: 150
# 	 Hiker's experience: 74.2% age: 44 Probable paycheck: 0
# 	 Action:  [1]
# 	 reward= [150.] done= [False]
# Step 19
# 	 Balance: 300
# 	 Hiker's experience: 9.2% age: 85 Probable paycheck: 0
# 	 Action:  [1]
# 	 reward= [150.] done= [False]
# Step 20
# 	 Balance: 450
# 	 Hiker's experience: 63.5% age: 54 Probable paycheck: -330
# 	 Action:  [0]
# 	 reward= [-25.] done= [False]
# Step 21
# 	 Balance: 425
# 	 Hiker's experience: 46.1% age: 63 Probable paycheck: 0
# 	 Action:  [0]
# 	 reward= [-30.] done= [False]
# Step 22
# 	 Balance: 395
# 	 Hiker's experience: 91.8% age: 57 Probable paycheck: -68
# 	 Action:  [0]
# 	 reward= [-35.] done= [False]
# Step 23
# 	 Balance: 360
# 	 Hiker's experience: 66.0% age: 29 Probable paycheck: -158
# 	 Action:  [0]
# 	 reward= [-40.] done= [False]
# Step 24
# 	 Balance: 320
# 	 Hiker's experience: 69.9% age: 23 Probable paycheck: -236
# 	 Action:  [0]
# 	 reward= [-45.] done= [False]
# Step 25
# 	 Balance: 275
# 	 Hiker's experience: 1.9% age: 31 Probable paycheck: -473
# 	 Action:  [0]
# 	 reward= [-50.] done= [False]
# Step 26
# 	 Balance: 225
# 	 Hiker's experience: 86.5% age: 36 Probable paycheck: -101
# 	 Action:  [0]
# 	 reward= [-55.] done= [False]
# Step 27
# 	 Balance: 170
# 	 Hiker's experience: 71.7% age: 27 Probable paycheck: 0
# 	 Action:  [0]
# 	 reward= [-60.] done= [False]
# Step 28
# 	 Balance: 110
# 	 Hiker's experience: 86.6% age: 20 Probable paycheck: -464
# 	 Action:  [1]
# 	 reward= [-4000.] done= [ True]
# --------------------Episode ends! reward= [-4000.] --------------------
# Step 29
# 	 Balance: 35
# 	 Hiker's experience: 87.4% age: 66 Probable paycheck: 0
# 	 Action:  [1]
# 	 reward= [150.] done= [False]
# Step 30
# 	 Balance: 185
# 	 Hiker's experience: 45.3% age: 58 Probable paycheck: -26
# 	 Action:  [1]
# 	 reward= [124.] done= [False]
# Step 31
# 	 Balance: 309
# 	 Hiker's experience: 50.5% age: 48 Probable paycheck: -18
# 	 Action:  [0]
# 	 reward= [-15.] done= [False]
# Step 32
# 	 Balance: 294
# 	 Hiker's experience: 29.1% age: 68 Probable paycheck: -98
# 	 Action:  [0]
# 	 reward= [-20.] done= [False]
# Step 33
# 	 Balance: 274
# 	 Hiker's experience: 68.3% age: 23 Probable paycheck: -196
# 	 Action:  [0]
# 	 reward= [-25.] done= [False]
# Step 34
# 	 Balance: 249
# 	 Hiker's experience: 69.7% age: 48 Probable paycheck: -175
# 	 Action:  [0]
# 	 reward= [-30.] done= [False]
# Step 35
# 	 Balance: 219
# 	 Hiker's experience: 71.4% age: 20 Probable paycheck: 0
# 	 Action:  [0]
# 	 reward= [-35.] done= [False]
# Step 36
# 	 Balance: 184
# 	 Hiker's experience: 39.8% age: 79 Probable paycheck: -95
# 	 Action:  [1]
# 	 reward= [55.] done= [False]
# Step 37
# 	 Balance: 239
# 	 Hiker's experience: 9.9% age: 24 Probable paycheck: -191
# 	 Action:  [0]
# 	 reward= [-40.] done= [False]
# Step 38
# 	 Balance: 199
# 	 Hiker's experience: 50.2% age: 50 Probable paycheck: 0
# 	 Action:  [0]
# 	 reward= [-45.] done= [False]
# Step 39
# 	 Balance: 154
# 	 Hiker's experience: 43.3% age: 76 Probable paycheck: -256
# 	 Action:  [1]
# 	 reward= [-106.] done= [False]
# Step 40
# 	 Balance: 48
# 	 Hiker's experience: 17.5% age: 10 Probable paycheck: -113
# 	 Action:  [1]
# 	 reward= [37.] done= [False]
# Step 41
# 	 Balance: 85
# 	 Hiker's experience: 13.8% age: 27 Probable paycheck: -434
# 	 Action:  [1]
# 	 reward= [-4000.] done= [ True]
# --------------------Episode ends! reward= [-4000.] --------------------
# Step 42
# 	 Balance: 35
# 	 Hiker's experience: 22.9% age: 32 Probable paycheck: 0
# 	 Action:  [1]
# 	 reward= [150.] done= [False]
# Step 43
# 	 Balance: 185
# 	 Hiker's experience: 96.4% age: 15 Probable paycheck: -206
# 	 Action:  [0]
# 	 reward= [-15.] done= [False]
# Step 44
# 	 Balance: 170
# 	 Hiker's experience: 98.7% age: 19 Probable paycheck: 0
# 	 Action:  [0]
# 	 reward= [-20.] done= [False]
# Step 45
# 	 Balance: 150
# 	 Hiker's experience: 33.5% age: 75 Probable paycheck: -1000
# 	 Action:  [1]
# 	 reward= [-4000.] done= [ True]
# --------------------Episode ends! reward= [-4000.] --------------------
# Step 46
# 	 Balance: 35
# 	 Hiker's experience: 69.9% age: 72 Probable paycheck: -1000
# 	 Action:  [1]
# 	 reward= [-4000.] done= [ True]
# --------------------Episode ends! reward= [-4000.] --------------------
# Step 47
# 	 Balance: 35
# 	 Hiker's experience: 49.8% age: 82 Probable paycheck: 0
# 	 Action:  [1]
# 	 reward= [150.] done= [False]
# Step 48
# 	 Balance: 185
# 	 Hiker's experience: 47.7% age: 90 Probable paycheck: -17
# 	 Action:  [1]
# 	 reward= [133.] done= [False]
# Step 49
# 	 Balance: 318
# 	 Hiker's experience: 5.9% age: 85 Probable paycheck: -205
# 	 Action:  [0]
# 	 reward= [-15.] done= [False]
# Step 50
# 	 Balance: 303
# 	 Hiker's experience: 16.7% age: 25 Probable paycheck: -1000
# 	 Action:  [0]
# 	 reward= [-20.] done= [False]
# Step 51
# 	 Balance: 283
# 	 Hiker's experience: 20.9% age: 63 Probable paycheck: 0
# 	 Action:  [0]
# 	 reward= [-25.] done= [False]
# Step 52
# 	 Balance: 258
# 	 Hiker's experience: 10.0% age: 10 Probable paycheck: -354
# 	 Action:  [0]
# 	 reward= [-30.] done= [False]
# Step 53
# 	 Balance: 228
# 	 Hiker's experience: 88.0% age: 13 Probable paycheck: 0
# 	 Action:  [0]
# 	 reward= [-35.] done= [False]
# Step 54
# 	 Balance: 193
# 	 Hiker's experience: 91.1% age: 18 Probable paycheck: 0
# 	 Action:  [0]
# 	 reward= [-40.] done= [False]
# Step 55
# 	 Balance: 153
# 	 Hiker's experience: 90.2% age: 90 Probable paycheck: 0
# 	 Action:  [1]
# 	 reward= [150.] done= [False]
# Step 56
# 	 Balance: 303
# 	 Hiker's experience: 71.4% age: 70 Probable paycheck: 0
# 	 Action:  [0]
# 	 reward= [-45.] done= [False]
# Step 57
# 	 Balance: 258
# 	 Hiker's experience: 12.0% age: 12 Probable paycheck: 0
# 	 Action:  [0]
# 	 reward= [-50.] done= [False]
# Step 58
# 	 Balance: 208
# 	 Hiker's experience: 24.8% age: 86 Probable paycheck: 0
# 	 Action:  [1]
# 	 reward= [150.] done= [False]
# Step 59
# 	 Balance: 358
# 	 Hiker's experience: 41.2% age: 46 Probable paycheck: -287
# 	 Action:  [0]
# 	 reward= [-55.] done= [False]
# Step 60
# 	 Balance: 303
# 	 Hiker's experience: 63.0% age: 35 Probable paycheck: 0
# 	 Action:  [0]
# 	 reward= [-60.] done= [False]
# Step 61
# 	 Balance: 243
# 	 Hiker's experience: 73.4% age: 13 Probable paycheck: 0
# 	 Action:  [0]
# 	 reward= [-65.] done= [False]
# Step 62
# 	 Balance: 178
# 	 Hiker's experience: 41.2% age: 74 Probable paycheck: -293
# 	 Action:  [1]
# 	 reward= [-143.] done= [False]
# Step 63
# 	 Balance: 35
# 	 Hiker's experience: 84.8% age: 89 Probable paycheck: 0
# 	 Action:  [1]
# 	 reward= [150.] done= [False]
# Step 64
# 	 Balance: 185
# 	 Hiker's experience: 17.3% age: 56 Probable paycheck: 0
# 	 Action:  [1]
# 	 reward= [150.] done= [False]
# Step 65
# 	 Balance: 335
# 	 Hiker's experience: 66.7% age: 14 Probable paycheck: -1000
# 	 Action:  [0]
# 	 reward= [-70.] done= [False]
# Step 66
# 	 Balance: 265
# 	 Hiker's experience: 63.4% age: 32 Probable paycheck: -302
# 	 Action:  [0]
# 	 reward= [-75.] done= [False]
# Step 67
# 	 Balance: 190
# 	 Hiker's experience: 86.6% age: 24 Probable paycheck: 0
# 	 Action:  [0]
# 	 reward= [-80.] done= [False]
# Step 68
# 	 Balance: 110
# 	 Hiker's experience: 9.5% age: 59 Probable paycheck: -479
# 	 Action:  [1]
# 	 reward= [-4000.] done= [ True]
# --------------------Episode ends! reward= [-4000.] --------------------
# Step 69
# 	 Balance: 35
# 	 Hiker's experience: 8.8% age: 35 Probable paycheck: 0
# 	 Action:  [1]
# 	 reward= [150.] done= [False]
# Step 70
# 	 Balance: 185
# 	 Hiker's experience: 15.4% age: 53 Probable paycheck: -1000
# 	 Action:  [1]
# 	 reward= [-4000.] done= [ True]
# --------------------Episode ends! reward= [-4000.] --------------------
# Step 71
# 	 Balance: 35
# 	 Hiker's experience: 29.8% age: 86 Probable paycheck: -444
# 	 Action:  [1]
# 	 reward= [-4000.] done= [ True]
# --------------------Episode ends! reward= [-4000.] --------------------
# Step 72
# 	 Balance: 35
# 	 Hiker's experience: 52.6% age: 51 Probable paycheck: 0
# 	 Action:  [1]
# 	 reward= [150.] done= [False]
# Step 73
# 	 Balance: 185
# 	 Hiker's experience: 22.2% age: 65 Probable paycheck: 0
# 	 Action:  [1]
# 	 reward= [150.] done= [False]
# Step 74
# 	 Balance: 335
# 	 Hiker's experience: 5.0% age: 24 Probable paycheck: -1000
# 	 Action:  [0]
# 	 reward= [-15.] done= [False]
# Step 75
# 	 Balance: 320
# 	 Hiker's experience: 70.1% age: 79 Probable paycheck: 0
# 	 Action:  [0]
# 	 reward= [-20.] done= [False]
# Step 76
# 	 Balance: 300
# 	 Hiker's experience: 83.7% age: 29 Probable paycheck: -241
# 	 Action:  [0]
# 	 reward= [-25.] done= [False]
# Step 77
# 	 Balance: 275
# 	 Hiker's experience: 62.4% age: 18 Probable paycheck: -180
# 	 Action:  [0]
# 	 reward= [-30.] done= [False]
# Step 78
# 	 Balance: 245
# 	 Hiker's experience: 20.3% age: 33 Probable paycheck: -286
# 	 Action:  [0]
# 	 reward= [-35.] done= [False]
# Step 79
# 	 Balance: 210
# 	 Hiker's experience: 15.8% age: 47 Probable paycheck: -477
# 	 Action:  [0]
# 	 reward= [-40.] done= [False]
# Step 80
# 	 Balance: 170
# 	 Hiker's experience: 69.6% age: 67 Probable paycheck: -436
# 	 Action:  [1]
# 	 reward= [-4000.] done= [ True]
# --------------------Episode ends! reward= [-4000.] --------------------
# Step 81
# 	 Balance: 35
# 	 Hiker's experience: 34.1% age: 69 Probable paycheck: -454
# 	 Action:  [1]
# 	 reward= [-4000.] done= [ True]
# --------------------Episode ends! reward= [-4000.] --------------------
# Step 82
# 	 Balance: 35
# 	 Hiker's experience: 50.5% age: 33 Probable paycheck: -459
# 	 Action:  [1]
# 	 reward= [-4000.] done= [ True]
# --------------------Episode ends! reward= [-4000.] --------------------
# Step 83
# 	 Balance: 35
# 	 Hiker's experience: 77.2% age: 39 Probable paycheck: 0
# 	 Action:  [1]
# 	 reward= [150.] done= [False]
# Step 84
# 	 Balance: 185
# 	 Hiker's experience: 59.2% age: 70 Probable paycheck: -1000
# 	 Action:  [1]
# 	 reward= [-4000.] done= [ True]
# --------------------Episode ends! reward= [-4000.] --------------------
# Step 85
# 	 Balance: 35
# 	 Hiker's experience: 72.7% age: 62 Probable paycheck: 0
# 	 Action:  [1]
# 	 reward= [150.] done= [False]
# Step 86
# 	 Balance: 185
# 	 Hiker's experience: 13.7% age: 58 Probable paycheck: 0
# 	 Action:  [1]
# 	 reward= [150.] done= [False]
# Step 87
# 	 Balance: 335
# 	 Hiker's experience: 7.1% age: 21 Probable paycheck: -1000
# 	 Action:  [0]
# 	 reward= [-15.] done= [False]
# Step 88
# 	 Balance: 320
# 	 Hiker's experience: 71.2% age: 79 Probable paycheck: 0
# 	 Action:  [0]
# 	 reward= [-20.] done= [False]
# Step 89
# 	 Balance: 300
# 	 Hiker's experience: 53.0% age: 66 Probable paycheck: 0
# 	 Action:  [0]
# 	 reward= [-25.] done= [False]
# Step 90
# 	 Balance: 275
# 	 Hiker's experience: 24.1% age: 81 Probable paycheck: -314
# 	 Action:  [1]
# 	 reward= [-164.] done= [False]
# Step 91
# 	 Balance: 111
# 	 Hiker's experience: 69.8% age: 43 Probable paycheck: 0
# 	 Action:  [1]
# 	 reward= [150.] done= [False]
# Step 92
# 	 Balance: 261
# 	 Hiker's experience: 79.0% age: 15 Probable paycheck: -1000
# 	 Action:  [0]
# 	 reward= [-30.] done= [False]
# Step 93
# 	 Balance: 231
# 	 Hiker's experience: 79.1% age: 88 Probable paycheck: 0
# 	 Action:  [1]
# 	 reward= [150.] done= [False]
# Step 94
# 	 Balance: 381
# 	 Hiker's experience: 87.4% age: 76 Probable paycheck: 0
# 	 Action:  [0]
# 	 reward= [-35.] done= [False]
# Step 95
# 	 Balance: 346
# 	 Hiker's experience: 22.0% age: 75 Probable paycheck: 0
# 	 Action:  [0]
# 	 reward= [-40.] done= [False]
# Step 96
# 	 Balance: 306
# 	 Hiker's experience: 97.9% age: 66 Probable paycheck: -448
# 	 Action:  [0]
# 	 reward= [-45.] done= [False]
# Step 97
# 	 Balance: 261
# 	 Hiker's experience: 0.6% age: 43 Probable paycheck: -55
# 	 Action:  [0]
# 	 reward= [-50.] done= [False]
# Step 98
# 	 Balance: 211
# 	 Hiker's experience: 30.6% age: 35 Probable paycheck: -199
# 	 Action:  [0]
# 	 reward= [-55.] done= [False]
# Step 99
# 	 Balance: 156
# 	 Hiker's experience: 9.7% age: 53 Probable paycheck: -97
# 	 Action:  [1]
# 	 reward= [53.] done= [False]
# Step 100
# 	 Balance: 209
# 	 Hiker's experience: 12.4% age: 13 Probable paycheck: 0
# 	 Action:  [0]
# 	 reward= [-60.] done= [False]

# %%
obs = np.array([[1000.  ,  0.01, 10.  , 35.]])
action, _ = model.predict(obs, deterministic=True)
print(action)
# Out:
# [0]
